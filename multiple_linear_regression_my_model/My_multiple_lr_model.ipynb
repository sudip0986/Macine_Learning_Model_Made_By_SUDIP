# %% [markdown]
# It will also work for simple linear regression and multiple linear regression

# %%
import numpy as np
from sklearn.datasets import load_diabetes
X,y = load_diabetes(return_X_y=True)

# %%
X.shape
# Out:
# (442, 10)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 10)
# (89, 10)

# %% [markdown]
# My model of multiple lr class

# %%
class My_Mul_lr:
    def __init__(self):
            self.coef_=None,
            self.intercept_=None
    def fit(self,X_train,y_train):
          
          X_train = np.insert(X_train,0,1,1) # add 1 in the o index of xtrain array 

          #calculation
          betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
          print(betas)  
          self.intercept_=betas[0]
          self.coef_=betas[1:]
    
    def predict(self,y_train):
          return (self.intercept_ + np.dot(X_test,self.coef_))

# %%
lr=My_Mul_lr()

lr.fit(X_train,y_train)
# Out:
# [ 151.88331005   -9.15865318 -205.45432163  516.69374454  340.61999905
#  -895.5520019   561.22067904  153.89310954  126.73139688  861.12700152
#    52.42112238]

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(f"r2 score is :{r2_score(y_test,y_pred)}")
# Out:
# r2 score is :0.43993386615689645

# %%
lr.coef_
# Out:
# array([  -9.15865318, -205.45432163,  516.69374454,  340.61999905,
#        -895.5520019 ,  561.22067904,  153.89310954,  126.73139688,
#         861.12700152,   52.42112238])

# %%
lr.intercept_
# Out:
# np.float64(151.88331005254167)

# %% [markdown]
# Try with simple linear regression with same model

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['cgpa']],df['package'],test_size=0.2,random_state=2) # carefull here df[['cgpa']] .. here train set is 1d array make it 2d using [[]] for adding 1 in every row
print(X_train.shape)
print(X_test.shape)
# Out:
# (160, 1)
# (40, 1)

# %%
lr=My_Mul_lr()

lr.fit(X_train,y_train)
# Out:
# [-0.89611192  0.55795197]

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score
print(f"r2 score is :{r2_score(y_test,y_pred)}")
# Out:
# r2 score is :0.7807301475103894

# %%
lr.coef_
# Out:
# array([0.55795197])

# %%
lr.intercept_
# Out:
# np.float64(-0.8961119222429883)
